# %%
# STEP 1: Clone DeOldify repo and install dependencies
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# %cd DeOldify
# !pip install -r requirements-colab.txt
# !pip install ffmpeg
# STEP 2: Set up necessary files
from google.colab import files
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth

# STEP 3: Run colorization code
import torch
if not torch.cuda.is_available():
    print('GPU is required! Enable GPU in Runtime > Change runtime type > Hardware Accelerator = GPU')

# Import DeOldify modules
from deoldify import device
from deoldify.device_id import DeviceId
device.set(device=DeviceId.GPU0)

import fastai
from deoldify.visualize import *

colorizer = get_image_colorizer(artistic=True)

# Upload your image
uploaded = files.upload()
import os
input_image = list(uploaded.keys())[0]

# Colorize the image
colorizer.plot_transformed_image(path=input_image, render_factor=35, display_render_factor=True, figsize=(8,8))
# Out:
# Cloning into 'DeOldify'...
# remote: Enumerating objects: 2620, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2620 (delta 64), reused 46 (delta 46), pack-reused 2514 (from 3)
# Receiving objects: 100% (2620/2620), 69.73 MiB | 14.97 MiB/s, done.
# Resolving deltas: 100% (1174/1174), done.
# /content/DeOldify
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.3/173.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.4/631.4 kB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.6 MB/s eta 0:00:00
# ...

# %%
import torch.serialization

# Allow partial to be loaded safely (if you're okay with the risks)
import functools
torch.serialization.add_safe_globals([functools.partial])

# OR use a safer workaround: override `torch.load` just for this call
from deoldify.visualize import get_image_colorizer
import builtins

original_torch_load = torch.load

def patched_torch_load(*args, **kwargs):
    kwargs['weights_only'] = False
    return original_torch_load(*args, **kwargs)

torch.load = patched_torch_load
colorizer = get_image_colorizer(artistic=True)
torch.load = original_torch_load  # restore original

# %%
# STEP 1: Clone DeOldify repo and install dependencies
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# %cd DeOldify
# !pip install -r requirements-colab.txt
# !pip install ffmpeg

# STEP 2: Download model weights
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth
# Out:
# Cloning into 'DeOldify'...
# remote: Enumerating objects: 2620, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2620 (delta 64), reused 46 (delta 46), pack-reused 2514 (from 3)
# Receiving objects: 100% (2620/2620), 69.73 MiB | 24.83 MiB/s, done.
# Resolving deltas: 100% (1174/1174), done.
# /content/DeOldify/DeOldify
# ...
# mkdir: cannot create directory ‘models’: File exists
# --2025-05-12 09:58:15--  https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 185.93.1.242, 2400:52e0:1a00::1206:2
# Connecting to data.deepai.org (data.deepai.org)|185.93.1.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255144681 (243M) [application/octet-stream]
# Saving to: ‘./models/ColorizeArtistic_gen.pth’
#
# ./models/ColorizeAr 100%[===================>] 243.32M  4.92MB/s    in 49s
#
# ...

# %%
# Fix PyTorch 2.6 loading issues (monkey-patch torch.load temporarily)
import torch.serialization
import functools
torch.serialization.add_safe_globals([functools.partial])

import torch
from deoldify import device
from deoldify.device_id import DeviceId
device.set(device=DeviceId.GPU0)

from deoldify.visualize import get_image_colorizer

original_torch_load = torch.load

def patched_torch_load(*args, **kwargs):
    kwargs['weights_only'] = False
    return original_torch_load(*args, **kwargs)

torch.load = patched_torch_load
colorizer = get_image_colorizer(artistic=True)
torch.load = original_torch_load  # Restore original

# %%
# Colorize the image!
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a473fff3fac9> in <cell line: 0>()
#       1 # Colorize the image!
#       2 colorizer.plot_transformed_image(
# ----> 3     path=input_image,
#       4     render_factor=35,
#       5     display_render_factor=True,
#
# NameError: name 'input_image' is not defined

# %%
# Upload your black-and-white image
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-81c2f4ec-a1a8-47e5-b463-1253e07f7166" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81c2f4ec-a1a8-47e5-b463-1253e07f7166">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Colorize the image!
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# PosixPath('result_images/WhatsApp Image 2025-05-12 at 15.31.05_dfc7cab9.jpg')

# %%
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-437afc4b-c97a-4024-9d9d-21510098bd13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-437afc4b-c97a-4024-9d9d-21510098bd13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# PosixPath('result_images/Screenshot 2025-05-12 153414.png')

# %%
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-61f266b1-49e1-4a45-a8b7-07d7a7e22929" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61f266b1-49e1-4a45-a8b7-07d7a7e22929">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# PosixPath('result_images/WhatsApp Image 2025-05-12 at 15.37.23_9330ca2e.jpg')

# %%
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-f305ffc1-499e-4537-a53c-30771fa57647" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f305ffc1-499e-4537-a53c-30771fa57647">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# PosixPath('result_images/WhatsApp Image 2025-05-12 at 15.37.23_bf3bb59d.jpg')

# %%
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-fe1ba245-33b6-4be7-89dc-62a58a77c703" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe1ba245-33b6-4be7-89dc-62a58a77c703">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
colorizer.plot_transformed_image(
    path=input_image,
    render_factor=35,
    display_render_factor=True,
    figsize=(8,8)
)
# Out:
# PosixPath('result_images/Screenshot 2025-05-12 142119.png')

# %%
from google.colab import files
uploaded = files.upload()

import os
input_image = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-54f34d21-76de-40c5-9c86-d9521f6336c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54f34d21-76de-40c5-9c86-d9521f6336c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
